# %%
from pyecharts import Bar
import pandas as pd
import numpy as np
import pymongo

client = pymongo.MongoClient(host='localhost', port=27017)
db = client.JD_products
table = db.京东笔记本
df = pd.DataFrame(list(table.find()))
shop_message = df[df.shop_property == '自营'].groupby(['shop_name'])
shop_com = shop_message['shop_name'].agg(['count'])
shop_com.reset_index(inplace=True)
shop_com_last = shop_com.sort_values('count', ascending=False)[:12]

attr = np.array(shop_com_last['shop_name'])
v1 = np.array(shop_com_last['count'])
attr = ["{}".format(i.replace('京东', '').replace('旗舰店', '').replace('自营', '').replace('官方', '').replace('京东', '').replace('电脑', '').replace('产品专营店', '').replace('工作站', '').replace('笔记本', '')) for i in attr]
v1 = ["{}".format(i) for i in v1]
# bar = Bar("京东自营商店笔记本种类排行", title_pos='center', title_top='18', width=1200, height=400)
# bar.add("商家", attr, v1, is_convert=True, xaxis_min=10, yaxis_label_textsize=12, is_yaxis_boundarygap=True, yaxis_interval=0, is_label_show=True, is_legend_show=False, label_pos='right', is_yaxis_inverse=True, is_splitline_show=False)
# #is_legend_show 不显示商品标签 is_label_show=True 显示商品数值
# bar
bar = Bar("京东自营商店笔记本种类排行", title_pos='center', title_top='18', width=1000, height=400)
bar.add("商家", attr, v1,xaxis_rotate=30,is_label_show=True,is_legend_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="24a2c1f69d8a4fb09172dbfc9661be36" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_24a2c1f69d8a4fb09172dbfc9661be36 = echarts.init(document.getElementById('24a2c1f69d8a4fb09172dbfc9661be36'), 'light', {renderer: 'canvas'});
#
# var option_24a2c1f69d8a4fb09172dbfc9661be36 = {
#     "animation": true,
#     "title": [
#         {
#             "top": "18",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "text": "\u4eac\u4e1c\u81ea\u8425\u5546\u5e97\u7b14\u8bb0\u672c\u79cd\u7c7b\u6392\u884c",
#             "left": "center",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "top": "center",
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             }
#         }
#     },
#     "xAxis": [
#         {
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "axisLabel": {
#                 "rotate": 30,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "inverse": false,
#             "show": true,
#             "data": [
#                 "ThinkPad",
#                 "\u60e0\u666e",
#                 "\u6234\u5c14",
#                 "\u8054\u60f3",
#                 "\u5b8f\u7881\u5546\u7528",
#                 "\u534e\u7855",
#                 "Apple",
#                 "\u5fae\u8f6f",
#                 "",
#                 "\u5b8f\u7881",
#                 "\u534e\u4e3a",
#                 "\u4e09\u661f"
#             ],
#             "type": "category",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "yAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "show": true,
#             "type": "value",
#             "nameLocation": "middle",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "inverse": false,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series": [
#         {
#             "name": "\u5546\u5bb6",
#             "seriesId": 7544239,
#             "data": [
#                 "121",
#                 "84",
#                 "55",
#                 "51",
#                 "43",
#                 "40",
#                 "29",
#                 "29",
#                 "27",
#                 "26",
#                 "25",
#                 "23"
#             ],
#             "type": "bar",
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "position": "top"
#                 }
#             },
#             "barCategoryGap": "20%",
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "legend": [
#         {
#             "top": "top",
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6"
#             ],
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "show": false
#         }
#     ],
#     "series_id": 7544239,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_24a2c1f69d8a4fb09172dbfc9661be36.setOption(option_24a2c1f69d8a4fb09172dbfc9661be36);
#
#     });
# </script>

# %%
from pyecharts import Bar
import pandas as pd
import pymongo

client = pymongo.MongoClient('localhost', 27017)
db = client.JD_products
table = db.京东笔记本
df = pd.DataFrame(list(table.find()))
price_info = df['price']
bins = [0, 2000, 2500, 3000, 3500, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 12000, 14000, 16000, 19000, 200000]
level = ['0-2000', '2000-2500', '2500-3000', '3000-3500', '3500-4000', '4000-5000', '5000-6000', '6000-7000', '7000-8000', '8000-9000', '9000-10000', '10000-12000', '12000-14000', '14000-16000', '16000-19000', '19000以上']
price_stage = pd.cut(price_info, bins=bins, labels=level).value_counts().sort_index()
attr = price_stage.index
v1 = price_stage.values
bar = Bar('笔记本价格分布柱状图',  title_pos='center', title_top='10', width=1000, height=400)
bar.add('', attr, v1, is_stack=True, xaxis_rotate=30, yaxis_min=0, xaxis_interval=0, is_splitline_show=False, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1c22c955362248e4b6c5f7747765e771" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1c22c955362248e4b6c5f7747765e771 = echarts.init(document.getElementById('1c22c955362248e4b6c5f7747765e771'), 'light', {renderer: 'canvas'});
#
# var option_1c22c955362248e4b6c5f7747765e771 = {
#     "animation": true,
#     "title": [
#         {
#             "top": "10",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "text": "\u7b14\u8bb0\u672c\u4ef7\u683c\u5206\u5e03\u67f1\u72b6\u56fe",
#             "left": "center",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "top": "center",
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             }
#         }
#     },
#     "xAxis": [
#         {
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "axisLabel": {
#                 "rotate": 30,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8,
#                 "interval": 0
#             },
#             "inverse": false,
#             "show": true,
#             "data": [
#                 "0-2000",
#                 "2000-2500",
#                 "2500-3000",
#                 "3000-3500",
#                 "3500-4000",
#                 "4000-5000",
#                 "5000-6000",
#                 "6000-7000",
#                 "7000-8000",
#                 "8000-9000",
#                 "9000-10000",
#                 "10000-12000",
#                 "12000-14000",
#                 "14000-16000",
#                 "16000-19000",
#                 "19000\u4ee5\u4e0a"
#             ],
#             "type": "category",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "yAxis": [
#         {
#             "splitLine": {
#                 "show": false
#             },
#             "min": 0,
#             "nameLocation": "middle",
#             "axisLabel": {
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "show": true,
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "boundaryGap": true
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series": [
#         {
#             "seriesId": 104871,
#             "data": [
#                 115.0,
#                 139.0,
#                 171.0,
#                 238.0,
#                 563.0,
#                 1381.0,
#                 1081.0,
#                 563.0,
#                 463.0,
#                 307.0,
#                 236.0,
#                 256.0,
#                 184.0,
#                 96.0,
#                 92.0,
#                 72.0
#             ],
#             "type": "bar",
#             "stack": "stack_104871",
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "position": "top"
#                 }
#             },
#             "barCategoryGap": "20%",
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "legend": [
#         {
#             "top": "top",
#             "left": "center",
#             "data": [
#                 ""
#             ],
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series_id": 104871,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_1c22c955362248e4b6c5f7747765e771.setOption(option_1c22c955362248e4b6c5f7747765e771);
#
#     });
# </script>

# %%
from pyecharts import Pie
import pandas as pd
import pymongo

client = pymongo.MongoClient('localhost', 27017)
db = client.JD_products
table = db.京东笔记本
df = pd.DataFrame(list(table.find()))
shop_message = df.groupby(['shop_property'])
shop_com = shop_message['shop_property'].agg(['count'])
shop_com.reset_index(inplace=True)
shop_com_last = shop_com.sort_values('count', ascending=False)
attr = shop_com_last['shop_property']
v1 = shop_com_last['count']
pie = Pie('商店性质', title_pos='center', width=800, height=400)
pie.add('', attr, v1, radius=[40, 75], label_text_color=None, is_label_show=True, legend_orient='vertical', legend_pos='left')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="092d0ced320644848ab836db9aed62a9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_092d0ced320644848ab836db9aed62a9 = echarts.init(document.getElementById('092d0ced320644848ab836db9aed62a9'), 'light', {renderer: 'canvas'});
#
# var option_092d0ced320644848ab836db9aed62a9 = {
#     "animation": true,
#     "title": [
#         {
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "text": "\u5546\u5e97\u6027\u8d28",
#             "left": "center",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "toolbox": {
#         "top": "center",
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "title": "save as image",
#                 "show": true
#             },
#             "restore": {
#                 "title": "restore",
#                 "show": true
#             },
#             "dataView": {
#                 "title": "data view",
#                 "show": true
#             }
#         }
#     },
#     "series": [
#         {
#             "seriesId": 5522725,
#             "data": [
#                 {
#                     "name": "\u975e\u81ea\u8425",
#                     "value": 5256
#                 },
#                 {
#                     "name": "\u81ea\u8425",
#                     "value": 701
#                 }
#             ],
#             "type": "pie",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%",
#                     "position": "outside"
#                 }
#             },
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "top": "top",
#             "left": "left",
#             "data": [
#                 "\u975e\u81ea\u8425",
#                 "\u81ea\u8425"
#             ],
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series_id": 5522725,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_092d0ced320644848ab836db9aed62a9.setOption(option_092d0ced320644848ab836db9aed62a9);
#
#     });
# </script>

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import pandas as pd
import pymongo
import jieba
import re

client = pymongo.MongoClient('localhost', 27017)
db = client.JD_products
table = db.京东笔记本
data = pd.DataFrame(list(table.find()))
data = data[['_id']]


# 这里把标题中笔记本配置参数全部用正则筛选掉。虽说笔记本参数决定了笔记本的性能，不过真正的去购买一台笔记本时，
# 最重要的还是根据自己的需求和预算，然后再去考虑笔记本参数，最后选择一部适合自己的笔记本。一般的笔记本参数如下：
# CPU：酷睿系列i3、i5、i7，标压M与低压U
# 硬盘：500G、1T、2T
# 显卡：AMD，NVIDIA
# 内存：4G，8G

text = ''
for line in data['_id']:
    r = '[a-zA-Z0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~]+'
    line = re.sub(r, '', line.replace('笔记本电脑', '').replace('英寸', ''))
    text += ' '.join(jieba.cut(line, cut_all=False))
# print(text)
# backgroud_Image = plt.imread('computer.jpeg')
wc = WordCloud(
    background_color='white',
    font_path="C:\Windows\Fonts\方正楷体简体.TTF",
    # 设置中文字体，使得词云可以显示（词云默认字体是“DroidSansMono.ttf字体库”，不支持中文）
    max_words=2000,
    stopwords=STOPWORDS,
    max_font_size=130,
    random_state=30,
    width=1000, height=860, margin=2
)
wc.generate_from_text(text)
# img_colors = ImageColorGenerator(backgroud_Image)
# wc.recolor(color_func=img_colors)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file("computer.jpg")
print("生成词云成功")
# Out:
# 生成词云成功
